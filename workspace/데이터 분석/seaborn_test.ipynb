# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn

# %%
plt.rcParams["font.family"] = ["Malgun Gothic"]
plt.rcParams["axes.unicode_minus"] = False

# %%
seaborn.get_dataset_names() # 사용할 수 있는 데이터 셋 목록
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
titanics = seaborn.load_dataset("titanic")
titanics.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
tips = seaborn.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
seaborn.relplot(x="total_bill", y="tip", data=tips)

# %%
health = pd.read_excel("./data/health_screenings_2020_1000ea.xlsx")
health.head()
# Out:
#    year  city_code  gender  age_code  height  weight  waist  eye_left  \
# 0  2020         36       1         9     165      60   72.1       1.2
# 1  2020         27       2        13     150      65   81.0       0.8
# 2  2020         11       2        12     155      55   70.0       0.6
# 3  2020         31       1        13     160      70   90.8       1.0
# 4  2020         41       2        12     155      50   75.2       1.5
#
#    eye_right  hear_left  ...  serum   AST   ALT   GTP  smoking  drinking  \
# 0        1.5          1  ...    1.1  21.0  27.0  21.0        1         0
# 1        0.8          1  ...    0.5  18.0  15.0  15.0        1         0
# 2        0.7          1  ...    0.7  27.0  25.0   7.0        1         0
# 3        1.0          1  ...    1.2  65.0  97.0  72.0        1         0
# 4        1.2          1  ...    0.7  18.0  17.0  14.0        1         0
#
#    oral_check  dental_caries  tartar  open_date
# 0           0            NaN     NaN 2021-12-29
# ...

# %%
seaborn.relplot(data=health, x="systolic", y="diastolic")

# %%
seaborn.relplot(x="total_bill", y="tip", data=tips, hue="day")

# %%
seaborn.countplot(data=tips, x="day", hue="time")
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
current_palette = seaborn.color_palette()
seaborn.palplot(current_palette)
plt.show()

# %%
seaborn.palplot(seaborn.color_palette("pastel"))
plt.show()

# %%
seaborn.set_palette("pastel")
seaborn.countplot(data=tips, x="day", hue="time")
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
colors = ["Blue", "Red", "Green", "Orange"]
seaborn.palplot(seaborn.color_palette(colors))
plt.show()

# %%
seaborn.set_palette(colors)
seaborn.countplot(data=tips, x="day", hue="time")
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
seaborn.set_palette("muted")
seaborn.relplot(x="total_bill", y="tip", data=tips, hue="size", size="size")

# %%
seaborn.relplot(data=tips, x="total_bill", y="tip", col="smoker", row="sex")

# %%
seaborn.relplot(data=tips, x="total_bill", y="tip", col="day", col_wrap=2)

# %%
# x = 수축 혈압, y = 이완 혈압, hue = 성별, col = drinking, row = smoking
seaborn.relplot(data=health, x="systolic", y="diastolic", hue="gender", col="smoking", row="drinking")

# %%
data6 = health.loc[:, ['gender', 'height', 'weight', 'waist', 'drinking', 'smoking']]
data6.head()
# Out:
#    gender  height  weight  waist  drinking  smoking
# 0       1     165      60   72.1         0        1
# 1       2     150      65   81.0         0        1
# 2       2     155      55   70.0         0        1
# 3       1     160      70   90.8         0        1
# 4       2     155      50   75.2         0        1

# %%
data6.loc[data6['gender']==1, ['gender']] = "Male"
data6.loc[data6['gender']==2, ['gender']] = "Female"
data6.loc[data6['drinking']==0, ['drinking']] = "Non-drinking"
data6.loc[data6['drinking']==1, ['drinking']] = "Drinking"
data6.loc[(data6['smoking']==1)|(data6['smoking']==2), ['smoking']] = "Non-smoking"
data6.loc[data6['smoking']==3, ['smoking']] = "Smoking"
data6.head()
# Out:
# C:\Users\it\AppData\Local\Temp\ipykernel_5620\852889030.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Male' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data6.loc[data6['gender']==1, ['gender']] = "Male"
# C:\Users\it\AppData\Local\Temp\ipykernel_5620\852889030.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Non-drinking' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data6.loc[data6['drinking']==0, ['drinking']] = "Non-drinking"
# C:\Users\it\AppData\Local\Temp\ipykernel_5620\852889030.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Non-smoking' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
# ...

# %%
drinking = data6.groupby(["gender", "drinking"])["drinking"].count()
smoking = data6.groupby(["gender", "smoking"])["smoking"].count()
drinking = drinking.to_frame(name="count")
drinking.reset_index(inplace=True)
smoking = smoking.to_frame(name="count")
smoking.reset_index(inplace=True)

# %%
fig = plt.figure(figsize=(17, 6))
area1 = fig.add_subplot(1, 2, 1)
area2 = fig.add_subplot(1, 2, 2)
ax1 = seaborn.barplot(data=drinking, x="gender", y="count", hue="drinking", ax=area1);
ax2 = seaborn.barplot(data=smoking, x="gender", y="count", hue="smoking", ax=area2);
fig.suptitle("성별 음주 및 흡연 현황", fontsize=20)
area1.set_title("음주 현황", fontsize=15)
area2.set_title("흡연 현황", fontsize=15)
# Out:
# Text(0.5, 1.0, '흡연 현황')

# %%
plt.figure(figsize=(10, 5))
plt.title("몸무게와 허리 둘레")

seaborn.stripplot(data=data6, x="waist", y="weight", hue="gender")
plt.xticks(np.arange(0, 127, 63), labels=[53, 90.5, 128])
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.title("스웜 플롯 그래프")
seaborn.swarmplot(data=data6.head(100), x="waist", y="weight", hue="gender", size=2)
plt.xticks(np.arange(0, 46, 22.5), labels=[53, 75.5, 98])
plt.show()

# %%
plt.figure(figsize=(10, 6))
seaborn.histplot(data=male_data["weight"], bins=7, label="Male", color="blue", alpha=0.5, kde=True)
seaborn.histplot(data=female_data["weight"], bins=7, label="Female", color="red", alpha=0.5, kde=True)
plt.legend()
plt.grid()
plt.title("성별 체중 분포")
plt.xlabel("체중")
plt.ylabel("빈도수")
plt.savefig("./data/weight.png")
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.title("음주와 허리둘레 관계")
seaborn.boxplot(data=data6, x="waist", y="drinking", hue="gender", orient="h")  # orient="h"로 하면 가로로 보여좀
plt.xlim(20, 150)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.title("성별 체중 분포")
# seaborn.violinplot(data=data6[data6.weight<100], x="gender", y="waist", hue="drinking")
seaborn.violinplot(data=data6[data6.weight<100], x="gender", y="waist", hue="drinking", split=True, inner="quartile")
#  x랑 y를 바꾸면 가로가 됨~~
plt.show()

# %%
# 패싯 그리드 -> 어떤 칼럼으로 그래프를 나누겠다는 걸 딱 정해주는거임
fg = seaborn.FacetGrid(data6, col="drinking", row="gender")
fg.map(seaborn.histplot, "waist", bins=7, kde=True)

# %%
#  페어 그리드 -> 히스토그램 / 스트립을 n * n으로 전부 보여주는 놈
seaborn.pairplot(data6)

# %%
arr = np.random.rand(4, 4)
arr
# Out:
# array([[0.01923491, 0.71403794, 0.12373813, 0.83099166],
#        [0.08971178, 0.28002208, 0.08445725, 0.75957685],
#        [0.08344561, 0.9279724 , 0.52505858, 0.39133401],
#        [0.74744173, 0.78681524, 0.98931483, 0.62834327]])

# %%
df = pd.DataFrame(arr, columns=["A", "B", "C", "D"])

# 어노테이션 트루, 어노테이션의 포맷은 .2f, 컬러맵은 coolwarm
seaborn.heatmap(df, annot=True, fmt=".2f", cmap="Blues")
# Out:
# <Axes: >

# %%
corr = data6.corr(numeric_only=True)
corr
# Out:
#           height    weight     waist
# height  1.000000  0.687974  0.353650
# weight  0.687974  1.000000  0.787645
# waist   0.353650  0.787645  1.000000

# %%
# 트라이업: 대칭모양에서 윗쪽만 살리는거
# 트라이로우: 대칭모양에서 아래쪽만 살리는거
mask = np.triu(corr)
# 마스크에서 트라이업을 쓰면 트라이업 만큼을 날리는 거라서 아래쪽만 살아남음
# 마스크에서 트라이로우를 쓰면 트라이로우 만큼을 날리는 거라서 윗쪽만 살아남음
seaborn.heatmap(corr, mask=mask, annot=True, fmt=".2f", cmap="Reds")
# Out:
# <Axes: >

# %%
seaborn.heatmap(data=tips.corr(numeric_only=True), mask=np.triu(tip_corr), annot=True, fmt=".2f", cmap="Greens")
# Out:
# <Axes: >
